# %% [markdown]
# # Dynamic Person Group Extension

# %%
from base import _init_env, get_config

_init_env()

# %%
from azure_ai_vision_person import DynamicPersonGroupExtension

dpge = DynamicPersonGroupExtension(*get_config())

# %% [markdown]
# ### Clear all groups

# %%
await dpge.get_groups()
# Out:
# 2025-07-27 14:40:44.163 | DEBUG    | sdk_creator.adapter:_request:143 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/dynamicpersongroups/?start=None&top=10
# 2025-07-27 14:40:45.098 | DEBUG    | sdk_creator.adapter:_request:178 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/dynamicpersongroups/?start=None&top=10, success=True, 200, OK
# DynamicPersonGroups(groups=[DynamicPersonGroupModel(user_data='{"class_no": 1}', name='class1', dynamic_person_group_id='test_group')])

# %%
await dpge.clear_groups()
# Out:
# 2025-07-27 14:40:46.002 | DEBUG    | sdk_creator.adapter:_request:143 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/dynamicpersongroups/?start=None&top=1000
# 2025-07-27 14:40:46.323 | DEBUG    | sdk_creator.adapter:_request:178 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/dynamicpersongroups/?start=None&top=1000, success=True, 200, OK
# 2025-07-27 14:40:46.325 | DEBUG    | sdk_creator.adapter:_request:143 - DELETE https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/dynamicpersongroups/test_group
# 2025-07-27 14:40:46.835 | DEBUG    | sdk_creator.adapter:_request:178 - DELETE https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/dynamicpersongroups/test_group, success=True, 202, Accepted
# ...

# %%
await dpge.get_groups()
# Out:
# 2025-07-27 14:40:56.533 | DEBUG    | sdk_creator.adapter:_request:143 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/dynamicpersongroups/?start=None&top=10
# 2025-07-27 14:40:57.780 | DEBUG    | sdk_creator.adapter:_request:178 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/dynamicpersongroups/?start=None&top=10, success=True, 200, OK
# DynamicPersonGroups(groups=[])
