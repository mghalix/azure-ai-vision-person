# %% [markdown]
# # Dynamic Person Group

# %%
from base import _init_env, get_config

_init_env()

# %% [markdown]
# ### Dynamic Person Group Client

# %%
from azure_ai_vision_person import DynamicPersonGroup

dpg = DynamicPersonGroup(*get_config())

# %% [markdown]
# #### List available groups

# %%
await dpg.get_groups()
# Out:
# 2025-07-27 11:40:24.719 | DEBUG    | sdk_creator.adapter:_request:143 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/dynamicpersongroups/?start=None&top=10
# 2025-07-27 11:40:27.646 | DEBUG    | sdk_creator.adapter:_request:178 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/dynamicpersongroups/?start=None&top=10, success=True, 200, OK
# DynamicPersonGroups(groups=[])
