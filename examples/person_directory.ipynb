# %% [markdown]
# # Person Directory SDK

# %%
from base import _init_env, get_config

_init_env()

# %% [markdown]
# ### Person Directory Client

# %%
from azure_ai_vision_person import PersonDirectory

pd = PersonDirectory(*get_config())

# %% [markdown]
# #### Create person

# %%
person = await pd.create_person(name="Mohanad", user_data={"age": 22})

person
# Out:
# 2025-07-27 11:24:28.383 | DEBUG    | sdk_creator.adapter:_request:143 - POST https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/
# 2025-07-27 11:24:30.700 | DEBUG    | sdk_creator.adapter:_request:178 - POST https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/, success=True, 202, Accepted
# CreatePersonResult(person_id='da12bb2e-d107-4d7d-8b44-1f582b38e894')

# %%
await pd.get_person(person.person_id)
# Out:
# 2025-07-27 11:24:30.714 | DEBUG    | sdk_creator.adapter:_request:143 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/da12bb2e-d107-4d7d-8b44-1f582b38e894
# 2025-07-27 11:24:30.875 | DEBUG    | sdk_creator.adapter:_request:178 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/da12bb2e-d107-4d7d-8b44-1f582b38e894, success=True, 200, OK
# PersonDirectoryPerson(user_data='{"age": 22}', name='Mohanad', person_id='da12bb2e-d107-4d7d-8b44-1f582b38e894')

# %% [markdown]
# #### List all persons

# %%
await pd.get_persons()
# Out:
# 2025-07-27 11:24:33.262 | DEBUG    | sdk_creator.adapter:_request:143 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/?start=None&top=10
# 2025-07-27 11:24:33.570 | DEBUG    | sdk_creator.adapter:_request:178 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/?start=None&top=10, success=True, 200, OK
# PersonDirectoryPersons(persons=[PersonDirectoryPerson(user_data='{"age": 22}', name='Mohanad', person_id='da12bb2e-d107-4d7d-8b44-1f582b38e894'), PersonDirectoryPerson(user_data='{"age": 22}', name='Mohanad', person_id='78b8d592-f05b-4336-a00c-3ed890496b5e'), PersonDirectoryPerson(user_data='{"age": 22}', name='Mohanad', person_id='67735ce4-3cda-4de7-b5f6-ac5a7aedfbbc')])

# %%
await pd.update_person(
    person.person_id,
    name="7mada",
    user_data={"school": "Al Yarmouk"},
    reserve_user_data_if_unset=True,
)
# Out:
# 2025-07-25 23:59:35.106 | DEBUG    | sdk_creator.adapter:_request:143 - PATCH https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/db3259a1-c125-4cbd-89f5-38bf3e4a412c
# 2025-07-25 23:59:35.293 | DEBUG    | sdk_creator.adapter:_request:178 - PATCH https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/db3259a1-c125-4cbd-89f5-38bf3e4a412c, success=True, 200, OK

# %%
face = await pd.add_person_face(
    person.person_id,
    face_url="https://static.scientificamerican.com/dam/m/6c6324834b10211b/original/facial_expression_eyebrow_raised.jpg?m=1737990739.405&w=600",
)
# Out:
# 2025-07-25 23:59:40.144 | DEBUG    | sdk_creator.adapter:_request:143 - POST https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/db3259a1-c125-4cbd-89f5-38bf3e4a412c/recognitionModels/recognition_04/persistedfaces?detectionModel=detection_03&targetFace=None&userData=None
# 2025-07-25 23:59:40.924 | DEBUG    | sdk_creator.adapter:_request:178 - POST https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/db3259a1-c125-4cbd-89f5-38bf3e4a412c/recognitionModels/recognition_04/persistedfaces?detectionModel=detection_03&targetFace=None&userData=None, success=True, 202, Accepted

# %%
await pd.get_person_faces(person.person_id)
# Out:
# 2025-07-25 23:59:44.466 | DEBUG    | sdk_creator.adapter:_request:143 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/db3259a1-c125-4cbd-89f5-38bf3e4a412c
# 2025-07-25 23:59:44.712 | DEBUG    | sdk_creator.adapter:_request:178 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/db3259a1-c125-4cbd-89f5-38bf3e4a412c, success=True, 200, OK
# ListFaceResult(person_id='db3259a1-c125-4cbd-89f5-38bf3e4a412c', persisted_face_ids=['82053203-dbfe-4967-971f-339ee8641490'])

# %%
await pd.get_person(person.person_id)
# Out:
# 2025-07-25 23:59:53.143 | DEBUG    | sdk_creator.adapter:_request:143 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/db3259a1-c125-4cbd-89f5-38bf3e4a412c
# 2025-07-25 23:59:54.106 | DEBUG    | sdk_creator.adapter:_request:178 - GET https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/db3259a1-c125-4cbd-89f5-38bf3e4a412c, success=True, 200, OK
# PersonDirectoryPerson(user_data='{"school": "Al Yarmouk"}', person_id='db3259a1-c125-4cbd-89f5-38bf3e4a412c', name='7mada')

# %% [markdown]
# #### Delete a person

# %%
await pd.delete_person(person.person_id)
# Out:
# 2025-07-25 23:59:55.004 | DEBUG    | sdk_creator.adapter:_request:143 - DELETE https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/db3259a1-c125-4cbd-89f5-38bf3e4a412c
# 2025-07-25 23:59:56.030 | DEBUG    | sdk_creator.adapter:_request:178 - DELETE https://ai-multi-schoolai-dev.cognitiveservices.azure.com/face/v1.2-preview.1/persons/db3259a1-c125-4cbd-89f5-38bf3e4a412c, success=True, 202, Accepted
# True
